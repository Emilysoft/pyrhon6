# %%
import pandas as pd
import os

# %%
ruta = os.getcwd()
path=(f"{ruta}/datos.json")


df = pd.read_json(path)
df.head(10)
# Out:
#   RUT_ENCARGADO NOMBRE_ENCARGADO APELLIDO_ENCARGADO  ID_CONTINENTE  \
# 0    18000120-3           CARLOS          MALDONADO              1
# 1    18000121-4          MARTINA          RODRIGUEZ              2
# 2    18000122-5           ISABEL              LOPEZ              3
# 3    18000123-6          ANTONIO            SANCHEZ              4
# 4    18000124-7            MARIA              PEREZ              5
# 5    18000125-8         FERNANDO          GUTIERREZ              6
# 6    18000126-9            SOFIA             TORRES              2
# 7    18000127-0          ALFREDO             VARGAS              3
#
#    CONTINENTE  ID_PAIS NOMBRE_PAIS  ID_CIUDAD NOMBRE_CIUDAD  ID_ZOOLOGICO  \
# 0     AMERICA        1       CHILE        101         ANGOL          1001
# 1      EUROPA        2     FRANCIA        102         PARIS          1002
# 2        ASIA        3       JAPON        103         TOKIO          1003
# ...
